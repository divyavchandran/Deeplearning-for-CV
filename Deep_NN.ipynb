# %% [markdown]
# <a href="https://colab.research.google.com/github/divyavchandran/Deeplearning-for-CV/blob/main/Deep_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %% [markdown]
# to change directory

# %%
os.chdir('/content/drive/MyDrive/FDP_ Applications of DL_ML/handson thursday')

# %% [markdown]
# to confirm the directory

# %%
pwd
# Out:
# '/content/drive/MyDrive/FDP_ Applications of DL_ML/handson thursday'

# %%
import tensorflow as tf

# %%
mnist_data=tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist_data.load_data()

# %%
x_train.shape
#size of the training image
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_train[5]
#5th location digit
# Out:
# 2

# %%
import matplotlib.pyplot as plt
#to display or plot image
plt.imshow(x_train[5],cmap="binary")
#display in grayscale
plt.show()
y_train[5]
# Out:
# 2

# %%
import seaborn as sns
#to see the pixel values
plt.figure(figsize=(15,15))
sns.heatmap(x_train[5],annot=True,cmap='binary')
# enter True for displaying pixel values and binary to get the image in grayscale.

# %%
x_train=x_train/255.
x_test=x_test/255.
#to convert it into binary

# %%
x_valid,x_train=x_train[:5000],x_train[5000:]
y_valid,y_train=y_train[:5000],y_train[5000:]
#splitting the training set (60000 images here) to validation(5000 values) and training(55000 values)

# %%
x_valid.shape
#to check the values in validation dataset
# Out:
# (5000, 28, 28)

# %%
x_train.shape
# Out:
# (55000, 28, 28)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(x_train[5],annot=True,cmap='binary')
#to see the current value in x_train[5]

# %%
tf.keras.layers.Flatten(input_shape=[28,28],name="input layer"),tf.keras.layers.Dense(300,activation ='relu',name="hidden layer1"),tf.keras.layers.Dense(100,activation ='relu',name="hidden layer2"),tf.keras.layers.Dense(10,activation ='softmax',name="output layer")
# Out:
# (<keras.layers.reshaping.flatten.Flatten at 0x7f480a1ccf70>,
# ...
#  <keras.layers.core.dense.Dense at 0x7f480a1ee070>)
